# %%
#Mounting Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Le dossier ou il y a les fonctions crées
import sys
sys.path.append('../Functions')

# %%
#Importation des fonctions utiles
from data_load import load_csv
from models import L_R
from evaluation import cla_repo, conf_mat

# %%
#Chargement des données préparées
X_path='../Données/X_scaled.csv'
X=load_csv(X_path)
Y_path='../Données/Y.csv'
Y=load_csv(Y_path)

# %%
#Vérification de la matrice des variables (X satndarisée)
X.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.050758 -0.328637  4.184599  2.702515  0.984374  1.189791  0.723678
# 1  0.785653 -0.328637 -0.238972  2.128212 -0.056215 -0.840484  0.723678
# 2  1.625151 -0.328637  4.184599 -0.014380  0.464079  1.189791  0.723678
# 3  0.255444 -0.328637 -0.238972  1.443466  0.724226 -0.840484  0.723678
# 4  1.580967  3.042866 -0.238972  1.509732 -0.576509 -0.840484  0.723678
#
#           7         8         9        10        11        12        13  \
# 0 -0.065763  0.864444 -0.436931 -0.394157  0.983884  2.186187 -0.766893
# 1 -0.065763 -1.156812  2.288689 -0.394157 -1.016380 -0.457417  1.303962
# 2 -0.065763  0.864444 -0.436931 -0.394157 -1.016380 -0.457417  1.303962
# 3 -0.065763  0.864444 -0.436931 -0.394157  0.983884 -0.457417 -0.766893
# 4 -0.065763 -1.156812  2.288689 -0.394157 -1.016380 -0.457417  1.303962
#
#          14
# 0 -0.427363
# 1 -0.427363
# 2 -0.427363
# 3  2.339933
# 4 -0.427363

# %%
#Vérification du contenu de la colonne cible
Y.value_counts()
Y.head()
# Out:
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
#Appel de la fonction L_R pour la regression linéaire
Y_predict, Y_test=L_R(X, Y, test_size=0.3, max_ite=1000)

# %% [markdown]
# **Evaluation du résultat du modèle**

# %%
#Appel de la fonction cla_repo pour le rapport de classification
cla_repo(Y_test, Y_predict)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.73      0.84      1458
#            1       0.13      0.79      0.23        75
#
#     accuracy                           0.74      1533
#    macro avg       0.56      0.76      0.53      1533
# weighted avg       0.94      0.74      0.81      1533

# %%
import matplotlib.pyplot as plt

# %%
#Appel de la fonction conf_mat pour l'affichage de la matrice de confusion
Mat_Conf=conf_mat(Y_test, Y_predict)
plt.title('Mat_Conf_LR')
plt.savefig('../Figures/Matrice_de_Confusion_LR.png')
